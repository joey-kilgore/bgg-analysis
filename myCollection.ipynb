# %%
from utils import *

# %%
myGames = getCollection('mrjoeboo123')

for game in myGames:
    print(game.name+'\t'+game.myrating)
# Out:
# c:\Users\joeya\AppData\Local\Programs\Python\Python37\lib\site-packages\bs4\builder\__init__.py:546: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   XMLParsedAsHTMLWarning.MESSAGE, XMLParsedAsHTMLWarning
# 18Lilliput	N/A
# 5-Minute Dungeon	N/A
# 5-Minute Mystery	8
# 504	N/A
# 5211	7
# 7 Wonders	6
# The 7th Citadel	10
# The 7th Continent	10
# The 7th Continent: BGG Promo Cards	N/A
# The 7th Continent: What Goes Up, Must Come Down	N/A
# Above and Below	7
# Aerion	3
# Agricola	6
# Agricola: All Creatures Big and Small – The Big Box	7
# Agricola: Farmers of the Moor	N/A
# Akrotiri	8
# Alhambra	7
# ...and then, we held hands.	3
# Android: Netrunner	7
# Animal Upon Animal	7
# Arboretum	6
# Arkham Horror: The Card Game	7
# Arkwright: The Card Game	N/A
# Azul	8
# Bärenpark	8
# Battle Line	N/A
# BattleCON: Devastation of Indines	7
# Battlecrest: Fellwoods Base Game	N/A
# Battleship	N/A
# Beez	5
# Beowulf: The Legend	N/A
# Biblios	8
# Black Sonata	7
# Black Sonata: The Fair Youth	N/A
# Blokus	7
# Blokus Duo	7
# Blokus Junior	N/A
# Bohnanza	6
# Bohnanza: 25th Anniversary Edition	N/A
# burncycle	8
# Candy Match	7
# Captain Sonar	N/A
# Caravan	8
# Carcassonne	8
# Carcassonne: 8. Erweiterung – Brücken, Burgen und Basare	N/A
# Carcassonne: Expansion 3 – The Princess & The Dragon	N/A
# Carcassonne: Expansion 5 – Abbey & Mayor	N/A
# Carcassonne: Expansion 9 – Hills & Sheep	N/A
# Carcassonne: Hunters and Gatherers	8
# Carcassonne: Inns & Cathedrals	N/A
# Carcassonne: Over Hill and Dale	8
# Carcassonne: The River II	N/A
# Carcassonne: Traders & Builders	N/A
# Cartaventura: Lhasa	N/A
# Cartaventura: Vinland	7
# Cascadia	N/A
# Castellion	7
# Castles of Mad King Ludwig	N/A
# Cat Lady	8
# CATAN	6
# Catapult Feud	7
# Caverna: Cave vs Cave	9
# Caverna: Cave vs Cave – Era II	N/A
# Caverna: The Cave Farmers	7
# Century: Golem Edition	9
# Charterstone	N/A
# Chess	7
# Citadels	7
# Citadels	N/A
# Clever hoch Drei	N/A
# Codenames	7
# Codenames: Duet	6
# Coffee Roaster	6
# Commands & Colors: Ancients	N/A
# Concept	N/A
# Cosmic Encounter	4
# Cottage Garden	5
# Crokinole	7
# The Crusoe Crew	N/A
# Crystallo	N/A
# D-Day Dice (Second Edition)	5
# Dale of Merchants	6
# DaVinci's Challenge	N/A
# Dawn's Early Light: The War of 1812	7
# Discover: Lands Unknown	2
# Dixit	8
# Dominion	10
# Dominion (Second Edition) Big Box	N/A
# Dominion: Prosperity	N/A
# Dominion: Seaside	N/A
# Doomtown: Reloaded	4
# Dorfromantik: The Board Game	7
# Dragon's Breath	7
# Dune: Imperium	6
# DVONN	N/A
# Eldritch Horror	5
# Exit: The Game – The Polar Station	6
# Fast Forward: FEAR	8
# Fast Forward: FLEE	N/A
# Fields of Arle	8
# Finished!	6
# Fire!	7
# Fishing Lessons	N/A
# Fjords	9
# Food Chain Island	8
# Food Truck Champion	N/A
# Foodfighters	5
# For Sale	7
# Forbidden Island	6
# Formula D	N/A
# Friday	6
# Galaxy Trucker	8
# GIPF	N/A
# Gizmos	9
# Gloomhaven	9
# Go	10
# Gobblet	7
# Gobblet Gobblers	6
# Grove: A 9 card solitaire game	8
# Guess Who?	N/A
# Hanabi	3
# Hardback	5
# Harry Potter Hogwarts	7
# Heat: Pedal to the Metal	9
# Herbaceous	N/A
# Hive	8
# Honeycombs	N/A
# Hostage Negotiator	7
# ICECOOL	6
# IGOR: The Monster Making Game	7
# Illusion	6
# Imperial Settlers	6
# The Initiative	N/A
# Isle of Skye: From Chieftain to King	8
# JAB: Realtime Boxing	6
# Jaipur	6
# Jetpack Joyride	N/A
# Just One	7
# Kahuna	7
# KeyForge: Call of the Archons	8
# Khan of Khans	7
# King of Tokyo	8
# King of Tokyo: Power Up!	N/A
# Kingdom Builder	N/A
# Kingdomino	7
# Kodama: The Tree Spirits	N/A
# Leaving Earth	9
# Leaving Earth: Outer Planets	N/A
# Leaving Earth: Stations	N/A
# The Lord of the Rings	8
# The Lord of the Rings: The Card Game	10
# The Lord of the Rings: The Card Game – Revised Core Set	10
# Lord of the Rings: The Confrontation	N/A
# Lost Cities	8
# Lost Cities: Rivals	N/A
# MaCar	N/A
# Magic: The Gathering	7
# Maharani	N/A
# Mahjong Solitaire	6
# Make 5	N/A
# Mandala	N/A
# Maquis	6
# Marrakech	9
# Mechanical Beast	N/A
# Medina (Second Edition)	7
# Millennium Blades	7
# The Mind	7
# Mindbug: First Contact	5
# Mini-Obstgarten	N/A
# Mint Delivery	N/A
# Mint Works	N/A
# Modern Art	9
# Money!	7
# Monster Factory	6
# Monza	N/A
# Munchkin	2
# Nautilion	7
# Near and Far	6
# Near and Far: Amber Mines	N/A
# Nemo's War (Second Edition)	5
# Nemo's War (Second Edition): Bold and Caring Expansion Pack #2	N/A
# No Thanks!	7
# Nusfjord	N/A
# Obsession	N/A
# Oh My Goods!	8
# Oh My Goods!: Escape to Canyon Brook	N/A
# Oh My Goods!: Longsdale in Revolt	N/A
# One Deck Dungeon	3
# Onirim (Second Edition)	6
# Onitama	9
# Onitama: Sensei's Path	N/A
# Orchard: A 9 card solitaire game	9
# Palm Island	7
# Pandemic	8
# Pandemic Legacy: Season 1	9
# Pandemic Legacy: Season 2	N/A
# Pandemic: Iberia	N/A
# Pandemic: In the Lab	N/A
# Pandemic: On the Brink	N/A
# Pandemic: State of Emergency	N/A
# Patchwork	8
# Patchwork: Automa	N/A
# Photosynthesis	7
# PitchCar	N/A
# Point Salad	5
# Pokémon Trading Card Game	N/A
# Power Grid	N/A
# PÜNCT	N/A
# The Quacks of Quedlinburg	6
# Quadropolis	7
# Queen's Ransom	N/A
# Quiddler	6
# Quirky!	1
# Qwirkle	6
# Race for the Galaxy	6
# Race for the Galaxy: The Gathering Storm	N/A
# Rack-O	5
# Read My Mind	N/A
# Red7	N/A
# Reef	8
# Reiner Knizia's Amazing Flea Circus	6
# Ricochet Robots	6
# Rivière d'Enfer	N/A
# Roads & Boats	10
# Roads & Boats: 20th Anniversary Edition	10
# Roam	7
# Robo Rally	6
# Robo Rally	N/A
# Robot Turtles	6
# RobotLab: The Card Game	5
# Roll Player	6
# ROVE: Results-Oriented Versatile Explorer	N/A
# Rummikub	8
# Sagrada	6
# Sand Castles	N/A
# Santorini	6
# Scrabble	5
# Sherlock Holmes Consulting Detective: Jack the Ripper & West End Adventures	N/A
# Sherlock Holmes Consulting Detective: The Thames Murders & Other Cases	6
# Silver & Gold	6
# Sky Tango	N/A
# Sleeping Gods	N/A
# Snake Oil	8
# So, You've Been Eaten	N/A
# Sonar Family	N/A
# Spirit Island	N/A
# Spit It Out!	6
# Splendor	9
# Splendor: Cities of Splendor	N/A
# Sprawlopolis	8
# Star Realms	7
# Star Wars: X-Wing Miniatures Game	7
# Steam Torpedo: First Contact	7
# Steam Torpedo: First Contact – R&D	N/A
# Steam Torpedo: First Contact – To Your Positions!	N/A
# Stomp!	6
# Stratego	4
# Stratego (Revised Edition)	N/A
# Stuffed Fables	7
# Sub Terra	7
# Suburbia	8
# Suburbia: Collector's Edition	9
# Sushi Go Party!	8
# Sushi Go Party!: Sake Promo	N/A
# Sushi Go Party!: Sukeroku Promo	N/A
# Swish Jr.	N/A
# Sylvion	7
# Tales of the Arabian Nights	5
# Targui	N/A
# Team Play	N/A
# Terra Mystica	N/A
# That's Pretty Clever!	9
# That's Pretty Clever! Kids	N/A
# Through the Ages: A New Story of Civilization	6
# Through the Desert	9
# Ticket to Ride	7
# Ticket to Ride: Europa 1912	N/A
# Ticket to Ride: Europe	N/A
# Ticket to Ride: USA 1910	N/A
# Tiffin	N/A
# Tikal	N/A
# Timeline: Canada	N/A
# Timeline: Classic	N/A
# Timeline: Events	N/A
# Timeline: Inventions	N/A
# Tiny Epic Tactics	N/A
# Tiny Towns	9
# Tiny Towns: Fortune	N/A
# Tiny Towns: Villagers	N/A
# Too Many Bones	10
# Too Many Bones: The Automaton of Shale	N/A
# Too Many Bones: Unbreakable	N/A
# Traders of Osaka	N/A
# Triplock	4
# Tsuro	3
# Twice as Clever!	8
# Twilight Imperium: Fourth Edition	4
# Ugly Gryphon Inn	N/A
# Unbroken	7
# Under Falling Skies	7
# Under Falling Skies: A 9-Card Print-and-Play Game	7
# Undermining	N/A
# UNO	6
# Unsurmountable	N/A
# Welcome To...	8
# Whistle Stop	5
# Wingspan	8
# Wingspan: European Expansion	N/A
# Wingspan: Oceania Expansion	N/A
# YINSH	8
# Yspahan	N/A
# Zombie Kidz Evolution	9
# Zombie Teenz Evolution	8
# Zoo Break	7

# %%
  
myGames.sort(key=score, reverse=True)
for i in range(10):
    print(str(i+1)+':\t'+myGames[i].name+'\t'+myGames[i].myrating)
# Out:
# 1:	The 7th Citadel	10
# 2:	The 7th Continent	10
# 3:	Dominion	10
# 4:	Go	10
# 5:	The Lord of the Rings: The Card Game	10
# 6:	The Lord of the Rings: The Card Game – Revised Core Set	10
# 7:	Roads & Boats	10
# 8:	Roads & Boats: 20th Anniversary Edition	10
# 9:	Too Many Bones	10
# 10:	Caverna: Cave vs Cave	9

# %%
users = getUsersFromThread(1)

for user in users:
    print(user)
    games = getCollection(user)
    games.sort(key=score, reverse=True)
    for i in range(len(games) if (len(games)<10) else 10):
        print(games[i].name)
# Out:
# derk
# dwarf
# thomasdean007
# Bribaba
# JimPAX
# jdarnold
# clydeiii
# philreh
